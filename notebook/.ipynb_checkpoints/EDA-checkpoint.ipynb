# %% [markdown]
# # EDA for Telco Customer Churn
#
# This notebook contains exploratory data analysis for the IBM Telco Customer Churn dataset. It inspects class balance, missing values, numeric distributions, and categorical correlations with churn.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')
print(df.shape)
print(df['Churn'].value_counts(normalize=True))
print(df.isna().sum())
